# %%
import nltk
import string
from textblob import TextBlob

nltk.download('stopwords')
from nltk.corpus import stopwords
stoplist = stopwords.words('english') + ['though']
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Importing Data Files
import pandas as pd
import numpy  as np
products_df = pd.read_csv('/content/products.tsv', sep='\t', header=0)
reviews_df = pd.read_csv('/content/reviews.tsv', sep='\t', header=0)

# %%
pd.set_option('display.max_rows', None)

# %%
reviews_df['EnglishReview'] = np.where(reviews_df['languageCode.1']=='en-US', reviews_df['reviewText'], reviews_df['translation.reviewText'])

## Data Cleaning
reviews_df.loc[reviews_df['id']=='46952c82-d750-41c5-b8f2-92579bb8039c','languageCode'] = 'ru-RU'
reviews_df.loc[reviews_df['id']=='46952c82-d750-41c5-b8f2-92579bb8039c','languageCode.1'] = 'ru-RU'
reviews_df.loc[reviews_df['id']=='46952c82-d750-41c5-b8f2-92579bb8039c','translation.reviewText'] = "The mask, in principle, is cool. Made of pleasant natural fabric, thin. But!!! you need to know that after the first wash it does not significantly decrease in size. Suitable for a child or a girl with a small face. Therefore, for a small face - 5+++! For a standard adult - 4 not because of quality, but because of size"

reviews_df = reviews_df.drop_duplicates(inplace=False, ignore_index=False)
product_id = 101955
bad_reviews = reviews_df.loc[(reviews_df['productId']==product_id) & ((reviews_df['ratingValue']==40) | (reviews_df['ratingValue']==50))]['EnglishReview']#.apply(remove_stopwords,stopwords=bad_stopwords)
# bad_reviews.to_csv(filename,index=False)
bad_reviews
# Out:
# 2884    The mask is comfortable. Fits tightly to the f...
# 2885    I do not know what is there with the certifica...
# 2886    The masks are pretty good. I ordered after wea...
# 2887          It fits well to the face and does not slip.
# 2888    The masks are great. Sits comfortably on the f...
#                               ...
# 3534                                    wonderful product
# 3535                                           Very good
# 3536                                        I love I Herb
# 3538            They are fine, the same as any other KN95
# 3539                                           Just right
# Name: EnglishReview, Length: 565, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stoplist, ngram_range=(2,3))
# matrix of ngrams
ngrams = c_vec.fit_transform(bad_reviews)
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
df_ngram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'bigram/trigram'})

# %%
df_ngram['polarity'] = df_ngram['bigram/trigram'].apply(lambda x: TextBlob(x).polarity)
df_ngram['subjective'] = df_ngram['bigram/trigram'].apply(lambda x: TextBlob(x).subjectivity)

# %%
df_ngram.loc[df_ngram['polarity']<-0.1]
# Out:
#       frequency                    bigram/trigram  polarity  subjective
# 11           13                      tightly face -0.178571    0.285714
# 38            6                        small face -0.250000    0.400000
# 55            5                      hard breathe -0.291667    0.541667
# 70            4                    much expensive -0.500000    0.700000
# 72            4                       masks tight -0.178571    0.285714
# 93            4                        face small -0.250000    0.400000
# 103           4                           39 hard -0.291667    0.541667
# 107           3                      turned small -0.250000    0.400000
# 109           3                   times expensive -0.500000    0.700000
# 110           3                 tightly face slip -0.178571    0.285714
# 135           3                    ordinary masks -0.250000    0.500000
# 141           3                need fix endlessly -0.125000    0.750000
# 162           3               fix endlessly price -0.125000    0.750000
# 163           3                     fix endlessly -0.125000    0.750000
# 173           3       endlessly price corresponds -0.125000    0.750000
# 174           3                   endlessly price -0.125000    0.750000
# 177           3                 difficult breathe -0.500000    1.000000
# 195           2                        well small -0.250000    0.400000
# 202           2                       usual masks -0.250000    0.250000
# 207           2              turned small husband -0.250000    0.400000
# 213           2              tightly face breathe -0.178571    0.285714
# 214           2                        tight face -0.178571    0.285714
# 215           2               tight elastic bands -0.178571    0.285714
# 216           2                     tight elastic -0.178571    0.285714
# 235           2                     small husband -0.250000    0.400000
# 236           2                       small faces -0.250000    0.400000
# 237           2                       sit tightly -0.178571    0.285714
# 238           2           several times expensive -0.250000    0.350000
# 279           2                     ordinary mask -0.250000    0.500000
# 310           2              masks much expensive -0.500000    0.700000
# 346           2                     little harder -0.143750    0.250000
# 347           2                       little face -0.187500    0.500000
# 380           2                 fits tightly face -0.178571    0.285714
# 381           2                      fits tightly -0.178571    0.285714
# 409           2                        even small -0.250000    0.400000
# 472           2                       behind ears -0.400000    0.700000
# 473           2                        behind ear -0.400000    0.700000
# 479           2                   39 hard breathe -0.291667    0.541667
# 513           1           yekaterinburg week half -0.166667    0.166667
# 535           1             would leave dangerous -0.600000    0.900000
# 555           1              works well extremely -0.125000    1.000000
# 612           1                 wish black makeup -0.166667    0.433333
# 613           1                        wish black -0.166667    0.433333
# 640           1                      well tightly -0.178571    0.285714
# 645           1                  well small woman -0.250000    0.400000
# 646           1                 well small errors -0.250000    0.400000
# 701           1                    well extremely -0.125000    1.000000
# 705           1                          well due -0.125000    0.375000
# 706           1            well difficult breathe -0.500000    1.000000
# 707           1                    well difficult -0.500000    1.000000
# 734           1                         week half -0.166667    0.166667
# 735           1               wearing usual masks -0.250000    0.250000
# 736           1                     wearing usual -0.250000    0.250000
# 747           1                 wearing less hour -0.166667    0.066667
# 748           1                      wearing less -0.166667    0.066667
# 755           1           wear somewhat difficult -0.500000    1.000000
# 757           1               wear reusable tight -0.178571    0.285714
# 781           1             wear glasses ordinary -0.250000    0.500000
# 800           1            wear become irrelevant -0.500000    1.000000
# 848           1              vilified little hung -0.187500    0.500000
# 849           1                   vilified little -0.187500    0.500000
# 874           1                 usually use cloth -0.250000    0.250000
# 875           1                       usually use -0.250000    0.250000
# 876           1                  usual one course -0.250000    0.250000
# 877           1                         usual one -0.250000    0.250000
# 878           1               usual medical would -0.125000    0.125000
# 879           1                     usual medical -0.125000    0.125000
# 880           1                  usual masks seal -0.250000    0.250000
# 907           1             used little beginning -0.187500    0.500000
# 908           1                       used little -0.187500    0.500000
# 944           1                 use everyday wear -0.200000    0.600000
# 945           1                      use everyday -0.200000    0.600000
# 954           1             usa almost impossible -0.666667    1.000000
# 981           1              unlike ordinary ones -0.250000    0.500000
# 982           1                   unlike ordinary -0.250000    0.500000
# 985           1         unlike conventional masks -0.142857    0.357143
# 986           1               unlike conventional -0.142857    0.357143
# 995           1               uneven hard general -0.147222    0.413889
# 996           1                       uneven hard -0.245833    0.370833
# 1004          1            uncomfortable material -0.500000    1.000000
# 1012          1                    uaed past seem -0.250000    0.250000
# 1013          1                         uaed past -0.250000    0.250000
# 1035          1             turns vilified little -0.187500    0.500000
# 1037          1               turned small rubber -0.250000    0.400000
# 1064          1             transport sit tightly -0.178571    0.285714
# 1073          1                  tough cover nose -0.388889    0.833333
# 1074          1                       tough cover -0.388889    0.833333
# 1117          1        times expensive convenient -0.500000    0.700000
# 1144          1                time everyday life -0.200000    0.600000
# 1145          1                     time everyday -0.200000    0.600000
# 1161          1             tightly skin breathes -0.178571    0.285714
# 1162          1                      tightly skin -0.178571    0.285714
# 1165          1              tightly hope protect -0.178571    0.285714
# 1166          1                      tightly hope -0.178571    0.285714
# 1167          1              tightly face without -0.178571    0.285714
# 1168          1                tightly face press -0.178571    0.285714
# 1169          1                tightly face metal -0.178571    0.285714
# 1170          1                 tightly face mask -0.178571    0.285714
# 1173          1                tightly face allow -0.178571    0.285714
# 1174          1                   tightly face 39 -0.178571    0.285714
# 1175          1               tightly covers face -0.178571    0.285714
# 1176          1                    tightly covers -0.178571    0.285714
# 1178          1                      tightly clip -0.178571    0.285714
# 1180          1                   tightly breathe -0.178571    0.285714
# 1186          1                        tight weak -0.276786    0.455357
# 1189          1                    tight sit well -0.178571    0.285714
# 1190          1                         tight sit -0.178571    0.285714
# 1191          1                   tight recommend -0.178571    0.285714
# 1192          1                tight masks unlike -0.178571    0.285714
# 1193          1                       tight masks -0.178571    0.285714
# 1194          1               tight kn95 products -0.178571    0.285714
# 1195          1                        tight kn95 -0.178571    0.285714
# 1196          1                   tight go floors -0.178571    0.285714
# 1197          1                          tight go -0.178571    0.285714
# 1203          1                 tight face leaves -0.178571    0.285714
# 1206          1                 tied loops little -0.187500    0.500000
# 1217          1               throw away ordinary -0.250000    0.500000
# 1247          1                   thin small face -0.325000    0.625000
# 1248          1                        thin small -0.325000    0.625000
# 1249          1         thin pharmaceutical masks -0.400000    0.850000
# 1250          1               thin pharmaceutical -0.400000    0.850000
# 1252          1                  thin lightweight -0.400000    0.850000
# 1254          1                         thin face -0.400000    0.850000
# 1255          1             thin disposable masks -0.400000    0.850000
# 1256          1                   thin disposable -0.400000    0.850000
# 1259          1                   thick well made -0.300000    0.475000
# 1260          1                        thick well -0.300000    0.475000
# 1261          1                  thick places lot -0.300000    0.475000
# 1262          1                      thick places -0.300000    0.475000
# 1263          1                  thick hope works -0.300000    0.475000
# 1264          1                        thick hope -0.300000    0.475000
# 1333          1                sweat less elastic -0.166667    0.066667
# 1334          1                        sweat less -0.166667    0.066667
# 1394          1               students scary odor -0.500000    1.000000
# 1395          1                    students scary -0.500000    1.000000
# 1417          1                     straps little -0.187500    0.500000
# 1422          1                    strap firm may -0.200000    0.400000
# 1423          1                        strap firm -0.200000    0.400000
# 1449          1                still hard breathe -0.291667    0.541667
# 1450          1                        still hard -0.291667    0.541667
# 1456          1               states put ordinary -0.250000    0.500000
# 1462          1        stapler even imperceptible -0.200000    0.200000
# 1473          1            stabbing angle problem -0.600000    0.800000
# 1474          1                    stabbing angle -0.600000    0.800000
# 1501          1        somewhat difficult breathe -0.500000    1.000000
# 1502          1                somewhat difficult -0.500000    1.000000
# 1524          1    solution compared conventional -0.142857    0.357143
# 1554          1                snugly little face -0.187500    0.500000
# 1555          1                     snugly little -0.187500    0.500000
# 1588          1               smaller usual masks -0.125000    0.375000
# 1589          1                     smaller usual -0.125000    0.375000
# 1602          1                    small woman 39 -0.250000    0.400000
# 1603          1                       small woman -0.250000    0.400000
# 1604          1                  small small face -0.250000    0.400000
# 1605          1                       small small -0.250000    0.400000
# 1606          1            small russian internet -0.125000    0.200000
# 1607          1                     small russian -0.125000    0.200000
# 1608          1                small rubber bands -0.250000    0.400000
# 1609          1                      small rubber -0.250000    0.400000
# 1610          1            small roundish wearing -0.250000    0.400000
# 1611          1                    small roundish -0.250000    0.400000
# 1612          1              small regulate tying -0.250000    0.400000
# 1613          1                    small regulate -0.250000    0.400000
# 1614          1              small person shorten -0.250000    0.400000
# 1615          1                      small person -0.250000    0.400000
# 1616          1      small particles conventional -0.196429    0.378571
# 1617          1                   small particles -0.250000    0.400000
# 1618          1                 small narrow face -0.225000    0.400000
# 1619          1                      small narrow -0.225000    0.400000
# 1620          1                   small like mine -0.250000    0.400000
# 1621          1                        small like -0.250000    0.400000
# 1624          1                   small know hold -0.250000    0.400000
# 1625          1                        small know -0.250000    0.400000
# 1626          1               small husband press -0.250000    0.400000
# 1628          1                        small head -0.250000    0.400000
# 1629          1                 small female face -0.125000    0.283333
# 1630          1                      small female -0.125000    0.283333
# 1632          1              small face teenagers -0.250000    0.400000
# 1633          1                   small face size -0.250000    0.400000
# 1634          1                   small face mask -0.250000    0.400000
# 1636          1                   small face goes -0.250000    0.400000
# 1637          1              small errors bracing -0.250000    0.400000
# 1638          1                      small errors -0.250000    0.400000
# 1639          1               small elastic bands -0.250000    0.400000
# 1640          1                     small elastic -0.250000    0.400000
# 1641          1               small complaint ear -0.275000    0.300000
# 1642          1                   small complaint -0.275000    0.300000
# 1647          1               slightly shape even -0.166667    0.166667
# 1648          1                    slightly shape -0.166667    0.166667
# 1649          1               slightly less bulky -0.166667    0.066667
# 1650          1                     slightly less -0.166667    0.066667
# 1657          1                       sizes small -0.250000    0.400000
# 1668          1                        size small -0.250000    0.400000
# 1680          1                       size little -0.187500    0.500000
# 1687          1                 size could little -0.187500    0.500000
# 1693          1                 sits tightly face -0.178571    0.285714
# 1694          1                      sits tightly -0.178571    0.285714
# 1695          1                   sits tight face -0.178571    0.285714
# 1696          1                        sits tight -0.178571    0.285714
# 1709          1                  sit tightly face -0.178571    0.285714
# 1710          1               sit tightly breathe -0.178571    0.285714
# 1739          1                 simimar uaed past -0.250000    0.250000
# 1743          1            similar much expensive -0.250000    0.550000
# 1778          1                short turned small -0.125000    0.350000
# 1790          1              sharp stabbing angle -0.362500    0.775000
# 1791          1                    sharp stabbing -0.362500    0.775000
# 1806          1                  shape even small -0.250000    0.400000
# 1840          1              sense security thick -0.300000    0.475000
# 1845          1                    sell expensive -0.500000    0.700000
# 1880          1             security thick places -0.300000    0.475000
# 1881          1                    security thick -0.300000    0.475000
# 1905          1           scratches little inside -0.187500    0.500000
# 1906          1                  scratches little -0.187500    0.500000
# 1909          1                  scary odor never -0.500000    1.000000
# 1910          1                        scary odor -0.500000    1.000000
# 1927          1                   sat little face -0.187500    0.500000
# 1928          1                        sat little -0.187500    0.500000
# 1959          1             russia sell expensive -0.500000    0.700000
# 1985          1            roundish wearing usual -0.250000    0.250000
# 2015          1                    reusable tight -0.178571    0.285714
# 2018          1            retainer either uneven -0.200000    0.200000
# 2020          1                  rests neck sharp -0.125000    0.750000
# 2033          1                 respirators tight -0.178571    0.285714
# 2036          1          respirators medium small -0.250000    0.400000
# 2050          1           respirator fits tightly -0.178571    0.285714
# 2174          1                quite tightly face -0.178571    0.285714
# 2175          1                     quite tightly -0.178571    0.285714
# 2176          1                    quite tight go -0.178571    0.285714
# 2177          1                       quite tight -0.178571    0.285714
# 2190          1         quietly cold condensation -0.600000    1.000000
# 2191          1                      quietly cold -0.600000    1.000000
# 2201          1                quality thick hope -0.300000    0.475000
# 2202          1                     quality thick -0.300000    0.475000
# 2205          1               quality size little -0.187500    0.500000
# 2211          1                quality sat little -0.187500    0.500000
# 2264          1          quality despite negative -0.300000    0.400000
# 2294          1           put ordinary disposable -0.250000    0.500000
# 2295          1                      put ordinary -0.250000    0.500000
# 2333          1                 protects well due -0.125000    0.375000
# 2357          1        protection small particles -0.250000    0.400000
# 2358          1                  protection small -0.250000    0.400000
# 2411          1                protection 39 hard -0.291667    0.541667
# 2457          1                product like black -0.166667    0.433333
# 2464          1                 product extremely -0.125000    1.000000
# 2485          1                printed black side -0.166667    0.433333
# 2486          1                     printed black -0.166667    0.433333
# 2528          1                   price one small -0.250000    0.400000
# 2544          1                      price little -0.187500    0.500000
# 2550          1                   price hard beat -0.291667    0.541667
# 2551          1                        price hard -0.291667    0.541667
# 2596          1                press tightly face -0.178571    0.285714
# 2597          1                     press tightly -0.178571    0.285714
# 2600          1                 press behind ears -0.400000    0.700000
# 2601          1                      press behind -0.400000    0.700000
# 2604          1              prefer hidden inside -0.166667    0.333333
# 2605          1                     prefer hidden -0.166667    0.333333
# 2625          1                     poor buy rami -0.400000    0.600000
# 2626          1                          poor buy -0.400000    0.600000
# 2680          1                  pieces expensive -0.500000    0.700000
# 2685          1             pieces common package -0.300000    0.500000
# 2686          1                     pieces common -0.300000    0.500000
# 2712          1        pharmaceutical masks tight -0.178571    0.285714
# 2718          1           permeable usual medical -0.125000    0.125000
# 2719          1                   permeable usual -0.250000    0.250000
# 2730          1                  perhaps less air -0.166667    0.066667
# 2731          1                      perhaps less -0.166667    0.066667
# 2784          1                         past seem -0.250000    0.250000
# 2785          1                past issues expect -0.250000    0.250000
# 2786          1                       past issues -0.250000    0.250000
# 2796          1       particles conventional thin -0.271429    0.603571
# 2797          1            particles conventional -0.142857    0.357143
# 2824          1              pandemic cold season -0.600000    1.000000
# 2825          1                     pandemic cold -0.600000    1.000000
# 2869          1                   pack price hard -0.291667    0.541667
# 2899          1         others aesthetically less -0.166667    0.066667
# 2902          1                     ordinary ones -0.250000    0.500000
# 2903          1                      ordinary one -0.250000    0.500000
# 2904          1                ordinary masks yes -0.250000    0.500000
# 2905          1               ordinary masks suit -0.250000    0.500000
# 2907          1             ordinary mask without -0.250000    0.500000
# 2908          1              ordinary mask finish -0.250000    0.500000
# 2911          1          ordinary disposable mask -0.250000    0.500000
# 2912          1               ordinary disposable -0.250000    0.500000
# 2913          1          ordinary blue disposable -0.125000    0.300000
# 2914          1                     ordinary blue -0.125000    0.300000
# 2945          1            options much expensive -0.500000    0.700000
# 2974          1               one small complaint -0.275000    0.300000
# 2975          1                         one small -0.250000    0.400000
# 3010          1                 odours fits small -0.250000    0.400000
# 3061          1             nose scratches little -0.187500    0.500000
# 3076          1                nose mouth tightly -0.178571    0.285714
# 3095          1                   nose clip tight -0.178571    0.285714
# 3175          1                  negative reviews -0.300000    0.400000
# 3201          1               neck sharp stabbing -0.362500    0.775000
# 3202          1                        neck sharp -0.125000    0.750000
# 3216          1                       narrow face -0.200000    0.400000
# 3257          1         much expensive pharmacies -0.500000    0.700000
# 3269          1                much bit difficult -0.150000    0.600000
# 3283          1                mouth tightly clip -0.178571    0.285714
# 3284          1                     mouth tightly -0.178571    0.285714
# 3333          1                   mind small face -0.250000    0.400000
# 3334          1                        mind small -0.250000    0.400000
# 3362          1                medium small faces -0.250000    0.400000
# 3363          1                      medium small -0.250000    0.400000
# 3380          1                medical mask small -0.125000    0.200000
# 3414          1           material feels slightly -0.166667    0.166667
# 3441          1             masks unlike ordinary -0.250000    0.500000
# 3446          1                 masks tough cover -0.388889    0.833333
# 3447          1                       masks tough -0.388889    0.833333
# 3452          1             masks times expensive -0.500000    0.700000
# 3455          1               masks tight elastic -0.178571    0.285714
# 3456          1            masks thin lightweight -0.400000    0.850000
# 3457          1                        masks thin -0.400000    0.850000
# 3475          1               masks small russian -0.125000    0.200000
# 3476          1                       masks small -0.250000    0.400000
# 3517          1                masks press behind -0.400000    0.700000
# 3519          1                    masks poor buy -0.400000    0.600000
# 3520          1                        masks poor -0.400000    0.600000
# 3531          1                    masks ordinary -0.250000    0.500000
# 3571          1              masks little cheaper -0.187500    0.500000
# 3572          1                      masks little -0.187500    0.500000
# 3648          1                   masks due shape -0.125000    0.375000
# 3649          1                         masks due -0.125000    0.375000
# 3654          1               masks designed thin -0.400000    0.850000
# 3658          1                 masks dense tight -0.178571    0.285714
# 3662          1                  masks cut behind -0.400000    0.700000
# 3707          1           masks bit uncomfortable -0.500000    1.000000
# 3715          1              masks adhere tightly -0.178571    0.285714
# 3717          1                     masks 39 hard -0.291667    0.541667
# 3735          1                 mask turned small -0.250000    0.400000
# 3745          1                   mask thick well -0.300000    0.475000
# 3746          1                        mask thick -0.300000    0.475000
# 3759          1                   mask small face -0.250000    0.400000
# 3760          1                        mask small -0.250000    0.400000
# 3761          1                 mask sits tightly -0.178571    0.285714
# 3762          1                   mask sits tight -0.178571    0.285714
# 3813          1                       mask little -0.187500    0.500000
# 3849          1                 mask expensive us -0.500000    0.700000
# 3850          1                    mask expensive -0.500000    0.700000
# 3914          1             marking printed black -0.166667    0.433333
# 3940          1                 male turned small -0.125000    0.250000
# 3950          1                 makes feel little -0.187500    0.500000
# 3955          1                   make small know -0.250000    0.400000
# 3956          1                        make small -0.250000    0.400000
# 4024          1               loops little behind -0.293750    0.600000
# 4025          1                      loops little -0.187500    0.500000
# 4028          1                loop little looser -0.187500    0.500000
# 4029          1                       loop little -0.187500    0.500000
# 4049          1                long time everyday -0.125000    0.500000
# 4068          1              little smaller usual -0.145833    0.416667
# 4070          1                      little safer -0.187500    0.500000
# 4072          1                       little lose -0.187500    0.500000
# 4073          1              little looser prefer -0.187500    0.500000
# 4074          1                     little looser -0.187500    0.500000
# 4077          1                little inside hour -0.187500    0.500000
# 4078          1                     little inside -0.187500    0.500000
# 4079          1             little hung somewhere -0.187500    0.500000
# 4080          1                       little hung -0.187500    0.500000
# 4082          1             little harder breathe -0.143750    0.250000
# 4084          1                little effort push -0.187500    0.500000
# 4085          1                     little effort -0.187500    0.500000
# 4086          1               little cheaper sell -0.187500    0.500000
# 4087          1                    little cheaper -0.187500    0.500000
# 4088          1                   little bit thin -0.293750    0.675000
# 4089          1                        little bit -0.187500    0.500000
# 4092          1                 little behind ear -0.293750    0.600000
# 4093          1                     little behind -0.293750    0.600000
# 4094          1            little beginning masks -0.187500    0.500000
# 4095          1                  little beginning -0.187500    0.500000
# 4174          1            like black inscription -0.166667    0.433333
# 4175          1                        like black -0.166667    0.433333
# 4195          1                   let less oxygen -0.166667    0.066667
# 4196          1                          let less -0.166667    0.066667
# 4201          1                less oxygen course -0.166667    0.066667
# 4202          1                       less oxygen -0.166667    0.066667
# 4203          1                 less masks bought -0.166667    0.066667
# 4204          1                        less masks -0.166667    0.066667
# 4208          1                         less hour -0.166667    0.066667
# 4209          1                less elastic bands -0.166667    0.066667
# 4210          1                      less elastic -0.166667    0.066667
# 4211          1               less chance viruses -0.166667    0.066667
# 4212          1                       less chance -0.166667    0.066667
# 4213          1                    less bulky say -0.166667    0.066667
# 4214          1                        less bulky -0.166667    0.066667
# 4217          1                less air permeable -0.166667    0.066667
# 4218          1                          less air -0.166667    0.066667
# 4223          1                leaves less chance -0.166667    0.066667
# 4224          1                       leaves less -0.166667    0.066667
# 4227          1             leave dangerous terms -0.600000    0.900000
# 4228          1                   leave dangerous -0.600000    0.900000
# 4276          1                korean kn95 little -0.187500    0.500000
# 4295          1                 kn95 use everyday -0.200000    0.600000
# 4316          1                       kn95 little -0.187500    0.500000
# 4331          1                   keep mind small -0.250000    0.400000
# 4345          1                    job hard carry -0.291667    0.541667
# 4346          1                          job hard -0.291667    0.541667
# 4426          1              inconvenient quality -0.600000    1.000000
# 4439          1               impossible get mask -0.666667    1.000000
# 4440          1                    impossible get -0.666667    1.000000
# 4480          1             husband press tightly -0.178571    0.285714
# 4559          1                   hole make small -0.250000    0.400000
# 4567          1                   hold well small -0.250000    0.400000
# 4570          1              hold tight recommend -0.178571    0.285714
# 4571          1                        hold tight -0.178571    0.285714
# 4600          1                hidden inside mask -0.166667    0.333333
# 4601          1                     hidden inside -0.166667    0.333333
# 4643          1                    hard stay long -0.170833    0.470833
# 4644          1                         hard stay -0.291667    0.541667
# 4646          1                      hard general -0.120833    0.520833
# 4648          1                     hard evaluate -0.291667    0.541667
# 4649          1                 hard carry people -0.291667    0.541667
# 4650          1                        hard carry -0.291667    0.541667
# 4651          1                hard breathe masks -0.291667    0.541667
# 4652          1               hard breathe enough -0.145833    0.520833
# 4653          1                         hard beat -0.291667    0.541667
# 4670          1             half quot politicians -0.166667    0.166667
# 4671          1                         half quot -0.166667    0.166667
# 4673          1                        half money -0.166667    0.166667
# 4676          1               guard prefer hidden -0.166667    0.333333
# 4747          1                got broken puttung -0.400000    0.400000
# 4748          1                        got broken -0.400000    0.400000
# 4892          1                glasses sweat less -0.166667    0.066667
# 4898          1            glasses ordinary masks -0.250000    0.500000
# 4899          1                  glasses ordinary -0.250000    0.500000
# 4926          1                   get used little -0.187500    0.500000
# 4998          1            fold conveniently half -0.166667    0.166667
# 5032          1                   fits well small -0.250000    0.400000
# 5038          1                fits snugly little -0.187500    0.500000
# 5041          1                   fits small face -0.250000    0.400000
# 5042          1                        fits small -0.250000    0.400000
# 5057          1          fits comfortably tightly -0.178571    0.285714
# 5156          1           firmly price affordable -0.200000    0.400000
# 5157          1                      firmly price -0.200000    0.400000
# 5158          1                    firm may issue -0.200000    0.400000
# 5159          1                          firm may -0.200000    0.400000
# 5175          1                   find black ones -0.166667    0.433333
# 5176          1                        find black -0.166667    0.433333
# 5199          1               feels slightly less -0.166667    0.066667
# 5200          1                    feels slightly -0.166667    0.166667
# 5222          1                 feel little safer -0.187500    0.500000
# 5223          1                       feel little -0.187500    0.500000
# 5245          1                    far got broken -0.150000    0.700000
# 5311          1                  face small small -0.250000    0.400000
# 5312          1               face small roundish -0.250000    0.400000
# 5313          1                   face small like -0.250000    0.400000
# 5314          1                face small elastic -0.250000    0.400000
# 5318          1                  face sit tightly -0.178571    0.285714
# 5328          1                  face quite tight -0.178571    0.285714
# 5339          1                face ordinary blue -0.125000    0.300000
# 5340          1                     face ordinary -0.250000    0.500000
# 5360          1                  face leaves less -0.166667    0.066667
# 5372          1                 face hard breathe -0.291667    0.541667
# 5373          1                         face hard -0.291667    0.541667
# 5409          1             face breathing little -0.187500    0.500000
# 5416          1                    face area less -0.166667    0.066667
# 5425          1                 face 39 difficult -0.500000    1.000000
# 5459          1                      expensive us -0.500000    0.700000
# 5462          1       expensive pharmacies stores -0.500000    0.700000
# 5463          1              expensive pharmacies -0.500000    0.700000
# 5464          1      expensive convenient packing -0.500000    0.700000
# 5465          1              expensive convenient -0.500000    0.700000
# 5541          1                everyday wear kovi -0.200000    0.600000
# 5542          1                     everyday wear -0.200000    0.600000
# 5543          1           everyday life something -0.200000    0.600000
# 5544          1                     everyday life -0.200000    0.600000
# 5554          1                 even small female -0.125000    0.283333
# 5555          1                   even small face -0.250000    0.400000
# 5567          1                         even less -0.166667    0.066667
# 5568          1                even imperceptible -0.200000    0.200000
# 5576          1             euronews channel half -0.166667    0.166667
# 5623          1                elastic strap firm -0.200000    0.400000
# 5627          1               elastic bands tight -0.178571    0.285714
# 5633          1              elastic bands poorly -0.400000    0.600000
# 5641          1                either uneven hard -0.245833    0.370833
# 5642          1                     either uneven -0.200000    0.200000
# 5694          1                       easy 39 bad -0.133333    0.750000
# 5713          1               easier conventional -0.142857    0.357143
# 5715          1              easier breathe usual -0.250000    0.250000
# 5717          1           easier breathe ordinary -0.250000    0.500000
# 5720          1          ears unlike conventional -0.142857    0.357143
# 5752          1                earbands bit tight -0.178571    0.285714
# 5755          1                 ear straps little -0.187500    0.500000
# 5761          1                   ear loop little -0.187500    0.500000
# 5774          1            durable ordinary masks -0.250000    0.500000
# 5775          1                  durable ordinary -0.250000    0.500000
# 5778          1                         due shape -0.125000    0.375000
# 5832          1                difficulties tight -0.178571    0.285714
# 5833          1               difficult put still -0.500000    1.000000
# 5834          1                     difficult put -0.500000    1.000000
# 5835          1        difficult breathe material -0.500000    1.000000
# 5836          1         difficult breathe inspire -0.500000    1.000000
# 5837          1             difficult breathe get -0.500000    1.000000
# 5838          1          difficult assess quality -0.500000    1.000000
# 5839          1                  difficult assess -0.500000    1.000000
# 5850          1             differ slightly shape -0.166667    0.166667
# 5851          1                   differ slightly -0.166667    0.166667
# 5852          1                   diff brand past -0.250000    0.250000
# 5856          1          despite negative reviews -0.300000    0.400000
# 5857          1                  despite negative -0.300000    0.400000
# 5860          1                designed thin face -0.400000    0.850000
# 5861          1                     designed thin -0.400000    0.850000
# 5868          1           density adheres tightly -0.178571    0.285714
# 5878          1                  dense tight face -0.178571    0.285714
# 5879          1                       dense tight -0.178571    0.285714
# 5891          1                     dense 39 hard -0.291667    0.541667
# 5904          1           degree protection small -0.250000    0.400000
# 5971          1         dangerous terms infection -0.600000    0.900000
# 5972          1                   dangerous terms -0.600000    0.900000
# 5973          1                   cut behind ears -0.400000    0.700000
# 5974          1                        cut behind -0.400000    0.700000
# 5980          1                       crush tight -0.178571    0.285714
# 5987          1               covid pandemic cold -0.600000    1.000000
# 5992          1                    covid 19 tight -0.178571    0.285714
# 6020          1                      could little -0.187500    0.500000
# 6047          1          conventional three layer -0.142857    0.357143
# 6048          1                conventional three -0.142857    0.357143
# 6049          1  conventional thin pharmaceutical -0.271429    0.603571
# 6050          1                 conventional thin -0.271429    0.603571
# 6053          1                conventional masks -0.142857    0.357143
# 6054          1      conventional disposable mask -0.142857    0.357143
# 6055          1           conventional disposable -0.142857    0.357143
# 6056          1           conveniently half money -0.166667    0.166667
# 6057          1                 conveniently half -0.166667    0.166667
# 6111          1     confidence conventional three -0.142857    0.357143
# 6112          1           confidence conventional -0.142857    0.357143
# 6123          1          composition perhaps less -0.166667    0.066667
# 6127          1                complaint ear loop -0.300000    0.200000
# 6128          1                     complaint ear -0.300000    0.200000
# 6133          1  compared conventional disposable -0.142857    0.357143
# 6134          1             compared conventional -0.142857    0.357143
# 6141          1           common package hygienic -0.300000    0.500000
# 6142          1                    common package -0.300000    0.500000
# 6146          1          comfortably tightly face -0.178571    0.285714
# 6147          1               comfortably tightly -0.178571    0.285714
# 6291          1                 cold season using -0.600000    1.000000
# 6292          1                       cold season -0.600000    1.000000
# 6293          1         cold condensation quickly -0.133333    0.750000
# 6294          1                 cold condensation -0.600000    1.000000
# 6306          1                clip tight elastic -0.178571    0.285714
# 6307          1                        clip tight -0.178571    0.285714
# 6373          1                 channel half quot -0.166667    0.166667
# 6374          1                      channel half -0.166667    0.166667
# 6451          1                    broken puttung -0.400000    0.400000
# 6454          1                broke wearing less -0.166667    0.066667
# 6474          1           breathing little harder -0.143750    0.250000
# 6475          1                  breathing little -0.187500    0.500000
# 6482          1      breathing difficulties tight -0.178571    0.285714
# 6503          1                 breathe usual one -0.250000    0.250000
# 6504          1                     breathe usual -0.250000    0.250000
# 6528          1              breathe quietly cold -0.600000    1.000000
# 6536          1              breathe ordinary one -0.250000    0.500000
# 6537          1                  breathe ordinary -0.250000    0.500000
# 6576          1       breathe easier conventional -0.142857    0.357143
# 6609          1                 brand past issues -0.250000    0.250000
# 6610          1                        brand past -0.250000    0.250000
# 6654          1                    black side one -0.166667    0.433333
# 6655          1                        black side -0.166667    0.433333
# 6657          1                        black ones -0.166667    0.433333
# 6658          1                 black makeup show -0.166667    0.433333
# 6659          1                      black makeup -0.166667    0.433333
# 6660          1            black inscription mask -0.166667    0.433333
# 6661          1                 black inscription -0.166667    0.433333
# 6662          1        bit uncomfortable material -0.500000    1.000000
# 6663          1                 bit uncomfortable -0.500000    1.000000
# 6665          1                         bit tight -0.178571    0.285714
# 6666          1                          bit thin -0.400000    0.850000
# 6676          1          bit inconvenient quality -0.600000    1.000000
# 6677          1                  bit inconvenient -0.600000    1.000000
# 6678          1                 bit difficult put -0.500000    1.000000
# 6679          1                     bit difficult -0.500000    1.000000
# 6681          1                      bit big thin -0.200000    0.475000
# 6691          1                    big thin small -0.216667    0.450000
# 6692          1                          big thin -0.200000    0.475000
# 6758          1                behind ears unlike -0.400000    0.700000
# 6759          1                  behind ears even -0.400000    0.700000
# 6760          1                  behind ear price -0.400000    0.700000
# 6761          1                  behind ear clips -0.400000    0.700000
# 6766          1             began differ slightly -0.166667    0.166667
# 6773          1                 become irrelevant -0.500000    1.000000
# 6790          1                  bands tight weak -0.276786    0.455357
# 6791          1                       bands tight -0.178571    0.285714
# 6804          1                      bands poorly -0.400000    0.600000
# 6815          1                  bands hold tight -0.178571    0.285714
# 6817          1                 bands crush tight -0.178571    0.285714
# 6845          1                  bad price little -0.443750    0.583333
# 6846          1                         bad price -0.700000    0.666667
# 6847          1                      bad mask far -0.300000    0.833333
# 6848          1                          bad mask -0.700000    0.666667
# 6849          1                     bad 39 stuffy -0.700000    0.666667
# 6850          1                            bad 39 -0.700000    0.666667
# 6855          1                away ordinary mask -0.250000    0.500000
# 6856          1                     away ordinary -0.250000    0.500000
# 6857          1               average quality k95 -0.150000    0.400000
# 6858          1                   average quality -0.150000    0.400000
# 6907          1                   area less masks -0.166667    0.066667
# 6908          1                         area less -0.166667    0.066667
# 6968          1                     also let less -0.166667    0.066667
# 6990          1             almost impossible get -0.666667    1.000000
# 6991          1                 almost impossible -0.666667    1.000000
# 7011          1               air permeable usual -0.250000    0.250000
# 7037          1                aesthetically less -0.166667    0.066667
# 7061          1              adheres tightly skin -0.178571    0.285714
# 7062          1                   adheres tightly -0.178571    0.285714
# 7067          1               adhere tightly hope -0.178571    0.285714
# 7068          1                    adhere tightly -0.178571    0.285714
# 7125          1                     39 still hard -0.291667    0.541667
# 7145          1                      39 hard stay -0.291667    0.541667
# 7146          1                  39 hard evaluate -0.291667    0.541667
# 7153          1                     39 find black -0.166667    0.433333
# 7159          1              39 difficult breathe -0.500000    1.000000
# 7160          1                      39 difficult -0.500000    1.000000
# 7166          1                         39 bad 39 -0.700000    0.666667
# 7167          1                            39 bad -0.700000    0.666667
# 7174          1                    2020 even less -0.166667    0.066667
# 7182          1                     19 tight kn95 -0.178571    0.285714
# 7183          1                          19 tight -0.178571    0.285714
# 7202          1               10 pieces expensive -0.500000    0.700000
# 7205          1                  10 pieces common -0.300000    0.500000
# 7212          1                    10 masks small -0.250000    0.400000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.pipeline import make_pipeline
tfidf_vectorizer = TfidfVectorizer(stop_words=stoplist, ngram_range=(2,3))
nmf = NMF(n_components=3)
pipe = make_pipeline(tfidf_vectorizer, nmf)
pipe.fit(bad_reviews)
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += ", ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()
print_top_words(nmf, tfidf_vectorizer.get_feature_names_out(), n_top_words=3)
# Out:
# Topic #0: good quality, good quality mask, quality mask
# Topic #1: good product, good product like, product recommend
# Topic #2: good masks, nice masks, reasonable price

# %% [markdown]
# **Review Tagging**
#
# As a list in the dataframe

# %%
chkdict = {
  'damage_words' : ['broke','tore','break','tear','torn','snapped','snap','fraying','fray'],
  'costly_words' : ['expensive','costly','pricy'],
  'economical_words': ['inexpensive','discount','bargain','cheap','affordable','economical','steal','offer'],
  'skin_words' : ['allergy','makeup','make-up','rashes','rash','swollen','cut','blood','sweat'],
  'fit_words' : ['small','fit','right','loose','big','small','large','little','smaller','larger'],
  'quality_words' : ['thick','thin','cotton','nylon','elastic','band'],
  'shipping_words' : ['shipped','late','arrived','early','packed','tax','import'],
  'fogging_words' : ['lenses','eyewear','glasses','fogging','mist'],
  'washing_words' : ['wash','washing','detergent','water','rinse','soap'],
  'water_test_words' : ['water test','water'],
  'injury_words' : ['injured','injure','blood','bruised','bruise'],
  'makeup_words' : ['makeup','make-up','make up','lipstick','mascara','eyeliner','smudge']
}
def check_in(text):
  lc_text = text.translate(str.maketrans('', '', string.punctuation))
  lc_text = lc_text.lower().split()
  rtags = []
  for key,value in chkdict.items():
    if any( i in value for i in lc_text):
      rtags.append(key)
  return rtags#','.join(rtags)

reviews_df['Tags'] = reviews_df['EnglishReview'].apply(check_in)
# reviews_df.loc[reviews_df['Tags']]
tag_df = reviews_df[reviews_df['Tags'].map(lambda tags: 'costly_words' in tags or 'economical_words' in tags)]
pd.set_option('max_colwidth', None)
# Slice Positive Reviews
tag_df = tag_df.loc[((tag_df['ratingValue']==40) | (tag_df['ratingValue']==50))]
# Slice Negative Reviews
# tag_df = tag_df.loc[((tag_df['ratingValue']==10) | (tag_df['ratingValue']==20) | (tag_df['ratingValue']==30))]
tagdf = tag_df[['productId','EnglishReview','Tags']]
tagdf = tagdf.loc[tagdf['productId']==101955]
# Reviews of Mask 101955 that have positive things about price.
tagdf
# Out:
#       productId  \
# 2898     101955
# 2915     101955
# 2948     101955
# 2955     101955
# 2973     101955
# 2997     101955
# 3022     101955
# 3026     101955
# 3045     101955
# 3144     101955
# 3159     101955
# 3160     101955
# 3219     101955
# 3298     101955
# 3406     101955
# 3407     101955
# 3424     101955
# 3434     101955
# 3494     101955
# 3521     101955
# 3522     101955
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        EnglishReview  \
# 2898                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Affordable, good quality
# 2915                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               good product and very inexpensive
# 2948                                                                                                                                                                                                                                                                                                                                   Mask with a high degree of protection KN95, I add this product to almost every parcel, the quality is excellent, the elastic bands are soft, I breathe easier in it than in a regular medical mask. Attractive price for iHerb, in Russia such masks are much more expensive.
# 2955                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Good inexpensive masks
# 2973                                                                                                                                                                                                                                                                                                                                                                                                                                           Great masks at a great price. In our city, such masks are 4 times more expensive. Convenient packing of 10 pieces. Excellent nose fixer and comfortable rubber bands.
# 2997                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Super masks, and for such a price, just a gift. Our similar is much more expensive.
# 3022                                                                                                      My brother introduced me to this style, and now that I have my own supply, I've shared some with my elderly Mom. These masks fit us better and are more comfortable than the blue and white medical masks that were so prevalent at the beginning of the epidemic. The adjustable nose piece keeps the mask safely anchored over my nose, and the sides fit the contours of my face without gaps. Breathing is more comfortable than with other masks. The four-pack discount makes them very affordable.
# 3026                                                                                                                                                                                                                                                                                                                                                                                                                                                     Nice, well-made masks, excellent metal rivets! Considering that in Russia such masks are several times more expensive, I am very pleased with the purchase!
# 3045                                                                                                                                                                                                                                                                                                                                                                         Masks of high quality and quite comfortable, at the time of purchase on the site, one such one could be bought in stores for about 200 rubles. And here are 10 pieces for 461 rubles without a discount. I will take more if necessary.
# 3144                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Nice masks. The elastic bands will not come off. In Russia they sell more expensive
# 3159                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good masks. These are much more expensive in pharmacies and stores.
# 3160                                                                                                                                                                                                                                                                                                                                                                                                                                                           very comfortable, covers everything, as if poured over the face. Breathing is a little harder than our cheap masks. but the main thing is safety !!!!
# 3219                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               good masks. easy to breathe in them. bought at a discount. 10 pieces in a package
# 3298                                                                                                                                                                     Here in the reviews, plus or minus ... but meets my requirements. I always wore a mask before the covid pandemic during the cold season, and I have been using them for a long time in everyday life. So there is something to compare with. It protects against household pollutants well, is fixed firmly, the price is affordable. I often see such masks one to one in appearance, only the price for them is not so &quot;tasty&quot;.
# 3406  You need to get used to them a little at the beginning. But the masks themselves are cool. And very comfortable. I read the entire Internet. It is advised to wear 1 mask for no more than 12 hours, but if you wear it partially, not all day, then take two masks and leave the worn one for 72 hours to eliminate the virus and bacteria. It turns out they vilified a little, hung somewhere for 72 hours. At this time, we wear another mask. and so we alternate. Someone disinfects these masks after wearing them in the oven at 60 degrees in a baking bag. The price for 10 pieces is not expensive.
# 3407                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Good budget mask, similar options are much more expensive
# 3424                                                                                                                                                                                                                                                                                                                                                                                       A good and cheap option for protective masks with increased protection against kn95, I use it in everyday wear from Kovi-19 and in a construction site from dust helps very well, where it is sterilized, you can use it!
# 3434                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         super masks, excellent protection In pharmacies, these are several times more expensive
# 3494                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Very comfortable mask. They are more expensive with us. I am very comfortable walking in it.
# 3521                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Very affordable price. I will buy again
# 3522                                                                                                                                                                                                                                                                                                                                                                                                 Very comfortable on the face. Also for children, adults. Does not absorb odors. Feels comfortable on the ears. You can breathe with it quite well compared to the cheap masks of the poor who buy at Rami Levy.
#
#                                Tags
# 2898             [economical_words]
# 2915             [economical_words]
# 2948  [costly_words, quality_words]
# 2955             [economical_words]
# 2973                 [costly_words]
# 2997                 [costly_words]
# 3022  [economical_words, fit_words]
# 3026                 [costly_words]
# 3045             [economical_words]
# 3144  [costly_words, quality_words]
# 3159                 [costly_words]
# 3160  [economical_words, fit_words]
# 3219             [economical_words]
# 3298             [economical_words]
# 3406      [costly_words, fit_words]
# 3407                 [costly_words]
# 3424             [economical_words]
# 3434                 [costly_words]
# 3494                 [costly_words]
# 3521             [economical_words]
# 3522             [economical_words]
